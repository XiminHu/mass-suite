# %%
import sys
sys.path.append('../mss')

# %%
import visreader as mvis
import mssmain as mss

# %%
path = 'D:/UW/directproject/example_data/ex_1.mzML'
scans = mss.get_scans(path)

# %%
mss.noise_removal(scans, 5000)

# %%
mvis.tic_plot(scans)
# Out:
# <div>
#
#
#             <div id="3b6ed04f-f29a-4f61-b706-7739497fc75d" class="plotly-graph-div" style="height:600px; width:1000px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("3b6ed04f-f29a-4f61-b706-7739497fc75d")) {
#                     Plotly.newPlot(
#                         '3b6ed04f-f29a-4f61-b706-7739497fc75d',
# ...

# %%
mvis.ms_plot(scans, 8.47, True)
# Out:
# <div>
#
#
#             <div id="4e111ac4-6acf-41e5-b0b3-40a24307de97" class="plotly-graph-div" style="height:600px; width:1000px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("4e111ac4-6acf-41e5-b0b3-40a24307de97")) {
#                     Plotly.newPlot(
#                         '4e111ac4-6acf-41e5-b0b3-40a24307de97',
# ...

# %%
mvis.ms_chromatogram(scans, 'C18H22N2O2', 0.002, False, 'pos',False,False,'pubchem')
# Out:
# 299.176

# %%
mvis.integration_plot(scans, 283.1816, 0.02)
# Out:
# Peak retention time: 8.48 minute, Peak area: 130352247.6

# %%
#Needs for bokeh dev
#Link from TIC to spectrum, spectrum to chromatogram
#Link with spectrum and spectrum list

# %%
def plot_readall(mzml_scans):
    rt=[]
    tic=[]
    for scan in mzml_scans:
        rt.append(scan.scan_time[0])
        tic.append(scan.TIC)
        
    for scan in mzml_scans:
    if scan.scan_time[0] >= time:
        mz = scan.mz
        ints = scan.i
        rt = scan.scan_time[0]
        break
# Out:
#   File "<ipython-input-22-baaaf662b131>", line 9
#     if scan.scan_time[0] >= time:
#      ^
# IndentationError: expected an indented block
