# %%
import pandas as pd
import numpy as np
import plotly

# %%
df = pd.read_csv('D:/UW/project/6ppd-experiments/ozonation/20210420_col_oz/summary/formula_annotated_noisocheck.csv')

# %%
def log2FC(dataframe, columns):
    d_fc = dataframe[columns].replace(0,1)
    d_fc['log2FC'] = np.log2(d_fc[columns[1]]) - np.log2(d_fc[columns[0]])
    return d_fc

# %%
log2FC(df,['0','1'])
# Out:
#                 0              1     log2FC
# 0     9401.000000  248765.000000   4.725825
# 1    24613.000000    9108.333333  -1.434162
# 2    36763.333330   39956.333330   0.120157
# 3     8304.333333  252043.000000   4.923662
# 4   169496.000000  367923.333300   1.118154
# 5   143774.000000  184224.333300   0.357661
# 6    18780.000000  149457.666700   2.992468
# 7    35594.333330  214769.000000   2.593066
# 8    25581.000000  145885.000000   2.511687
# 9    13617.000000   76602.666670   2.491986
# 10    4868.666667   83861.000000   4.106401
# 11  148797.000000  111671.333300  -0.414087
# 12   95667.666670   18904.333330  -2.339314
# 13  246230.333300  163492.000000  -0.590788
# 14  354806.666700   59710.000000  -2.570989
# 15  129725.000000   23268.666670  -2.478996
# 16  200509.666700   36360.333330  -2.463234
# 17    1687.666667   65136.666670   5.270368
# 18       1.000000  117068.666700  16.836995
# 19    5959.666667  294426.333300   5.626531
# ...
