# %% [markdown]
# This notebook displays the functionality in the alignment file. There are two parts essentially built in the function.

# %%
import sys
sys.path.append('../mss')
import alignment
import numpy as np
import pandas as pd

# %% [markdown]
# It takes in the given path where all of the files have been output into and reads them in one by one to create one dataframe. It returns the total number of files located in the path and the dataframe.

# %%
# read in example files to create one sample dataframe
path = '../example_data/peakdata/mssoutput/'
alignment.stack(path)
# Out:
# Reading in files...
# Process completed!
# (6,
#                m/z         rt     sn  score     peak area
#  0      100.111603   5.590000    inf    0.1  7.457226e+05
#  1      114.128304   4.730000    inf    0.6  2.142799e+05
#  2      117.111099   4.730000    inf    0.6  2.142799e+05
#  3      124.024803   0.610000  3.157    0.1  2.960091e+05
#  4      130.159500   3.460000  1.050    1.0  1.134880e+06
#  ...           ...        ...    ...    ...           ...
#  1158  1348.885010  19.270000  6.643    0.1  3.664002e+06
#  1159  1348.885010  19.430000    inf    0.6  4.283172e+06
#  1160  1349.910645  19.260000  1.632    1.0  1.061192e+06
#  1161  1349.910645  19.469999  0.774    0.1  1.678653e+05
#  1162  1350.882812  19.260000  4.223    0.6  4.348508e+05
#
#  [9717 rows x 5 columns])

# %% [markdown]
# The dataframe created from above the function is later used in the realignment function. It creates a reference dataframe based off the first sample. If any rows that exist from the above dataframe in the reference, it realigns them within a user inputted error for rt/mz. If they do not exist, then the rows will be added to the reference and will be used moving forward for any following samples. The reference dataframe will be turned in terms of the file type that the user prefers.

# %%
# %time alignment.realignment(path, 'may.2.2020', '.csv', 0.05, 0.015)
# Out:
#   0%|          | 33/9717 [00:00<00:29, 324.00it/s]
# Reading in files...
# Process completed!
# Initial reference built
# Alignment beginning..
# 100%|██████████| 9717/9717 [00:50<00:00, 191.06it/s]
# Alignment done!
# File saved
# CPU times: user 51.1 s, sys: 906 ms, total: 52 s
# Wall time: 53.6 s
#       Average m/z  Average RT (min)  Average sn  Average score  \
# 0      100.111603          5.590000         inf           0.10
# 1      100.111671          5.470000         inf           0.40
# 2      100.111801          5.340000       1.649           0.60
# 3      107.070297         13.760000         inf           1.00
# 4      114.091904          3.530000         inf           0.60
# ...           ...               ...         ...            ...
# 5379  1350.883789         19.264000         inf           0.48
# 5380  1350.884521         19.382999         inf           0.60
# 5381  1392.412842         20.740000       1.070           0.60
# 5382  1393.415649         20.700001       1.062           0.60
# 5383  1393.416748         20.799999       1.049           1.00
#
#       20181114_CoulterCreek_2  20181114_Crescent-Creek-May_2  \
# 0                745722.56250                         0.0000
# 1                     0.00000                    658076.9375
# 2                     0.00000                         0.0000
# 3                     0.00000                         0.0000
# 4                     0.00000                         0.0000
# ...                       ...                            ...
# 5379             407645.21875                         0.0000
# 5380             411676.21875                         0.0000
# 5381             154861.71875                         0.0000
# 5382                  0.00000                    245449.8125
# 5383                  0.00000                         0.0000
#
#       20181114_SR518-Cal_1000mL_dil-to-160mL_3  \
# 0                                     0.000000
# 1                                     0.000000
# 2                                136595.515625
# 3                                     0.000000
# 4                                     0.000000
# ...                                        ...
# 5379                             396962.562500
# 5380                                  0.000000
# 5381                                  0.000000
# 5382                                  0.000000
# 5383                                  0.000000
#
#       20181114_SR520-Cal-in-DI_1000mL_dil-to-60mL_1  \
# 0                                           0.00000
# 1                                           0.00000
# 2                                           0.00000
# 3                                           0.00000
# 4                                           0.00000
# ...                                             ...
# 5379                                   355496.00000
# 5380                                   408221.46875
# 5381                                        0.00000
# 5382                                        0.00000
# 5383                                        0.00000
#
#       20181114_SR520-Cal-in-DI_400mL_2  20181114_SwanCreek-Dec_3
# 0                             0.000000                  0.000000
# 1                        461195.968750             691249.000000
# 2                             0.000000                  0.000000
# 3                        111404.835938                  0.000000
# 4                        123020.796875                  0.000000
# ...                                ...                       ...
# 5379                     315320.406250             434850.781250
# 5380                     419165.937500                  0.000000
# 5381                          0.000000                  0.000000
# 5382                          0.000000                  0.000000
# 5383                          0.000000             120048.484375
#
# [5384 rows x 10 columns]
