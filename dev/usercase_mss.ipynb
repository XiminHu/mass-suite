# %%
import sys
sys.path.append('../mss')
import mssmain as mss

# %%
#read in mzml files
path = '../example_data/ex_1.mzML'
scans = mss.get_scans(path, ms_all=False, ms_lv=1)
#noise removal
mss.noise_removal(scans, 5000)

# %%
#read in mzml files in batch mode
batch_scan, file_list = mss.batch_scans('../example_data/batch', remove_noise=True, thres_noise=1000)

# %%
#generate peak list as dataframe output, detailed parameter please refer to peak picking function
d_test = mss.peak_list(scans[:200], 20)
# Out:
# Generating mz list...
# Finding peaks...
# 100%|██████████| 119/119 [00:00<00:00, 165.02it/s]
# Peak processing finished!
# Dataframe created!

# %%
d_test
# Out:
#          m/z    rt     sn  score     peak area
# 0   104.9935  0.64  0.000      2  8.390570e+06
# 1   119.0824  0.05  1.058      2  5.830668e+05
# 2   120.9836  0.98  0.922      1  1.616739e+05
# 3   121.0514  0.98  0.922      1  1.616739e+05
# 4   158.9977  0.61  0.000      3  9.067657e+05
# 5   166.1430  0.72  0.000      1  2.260080e+05
# 6   173.9848  0.72  0.000      1  2.260080e+05
# 7   179.0325  0.72  0.000      1  2.260080e+05
# 8   180.9765  0.62  0.000      2  2.922166e+06
# 9   186.9959  0.63  2.081      2  3.353246e+06
# 10  188.0009  0.65  1.978      2  1.473706e+05
# 11  200.0256  0.61  0.000      1  9.476508e+05
# 12  200.0256  0.72  1.955      2  8.238924e+05
# 13  200.0256  0.84  0.000      2  9.604643e+05
# 14  240.0199  0.75  0.745      2  1.568434e+05
# 15  247.0031  0.61  2.173      1  1.522894e+05
# 16  262.9805  0.63  0.000      1  3.745118e+06
# 17  263.9817  0.62  1.678      2  1.937259e+05
# 18  266.9976  0.69  1.234      3  1.207691e+05
# 19  269.0021  0.64  0.000      1  5.964501e+06
# 20  270.0047  0.64  0.000      2  3.535881e+05
# 21  295.9521  0.73  0.000      2  1.692383e+05
# 22  329.0058  0.62  2.356      2  1.681010e+05
# 23  337.9692  0.72  0.000      3  1.119214e+05
# 24  338.9711  0.62  0.000      3  6.810832e+05
# 25  344.9896  0.65  0.000      2  4.134330e+06
# 26  345.9846  0.63  0.000      1  3.341228e+05
# 27  351.0027  0.63  0.000      3  1.696637e+06
# 28  420.9653  0.62  0.000      1  7.835646e+05
# 29  426.9855  0.64  2.373      1  1.620671e+06
# 30  427.9944  0.63  2.013      2  1.577486e+05
# 31  433.0052  0.64  5.983      2  1.496808e+06
# 32  493.0188  0.62  0.000      1  1.442949e+05
# 33  502.9782  0.62  0.000      2  7.910175e+05
# 34  508.9891  0.64  0.000      2  2.305845e+06
# 35  509.9877  0.63  2.613      2  2.098706e+05
# 36  515.0100  0.64  0.000      1  1.512509e+06
# 37  584.9836  0.62  0.000      1  8.625539e+05
# 38  591.0045  0.65  4.711      1  1.406113e+06
# 39  591.9982  0.68  1.270      3  1.897362e+05
# 40  597.0157  0.64  9.320      3  5.756673e+05
# 41  666.9674  0.63  1.782      1  5.102516e+05
# 42  672.9971  0.64  0.000      2  1.000571e+06
# 43  748.9700  0.64  2.427      1  3.986243e+05
# 44  830.9892  0.63  2.589      3  2.535163e+05
# 45  836.9938  0.64  7.771      1  3.330416e+05
# 46  912.9991  0.64  0.000      1  1.302691e+05
